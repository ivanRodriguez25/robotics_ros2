# %% [markdown]
# ```$ros2 topic list```

# %% [markdown]
# ```$ros2 launch usb_cam_launch usb_cam_launch.py```

# %% [markdown]
# ```$ros2 run rqt_image_view rqt_image_view```

# %% [markdown]
# Within the *rqt_image_view* select the topic where the image is being published.
