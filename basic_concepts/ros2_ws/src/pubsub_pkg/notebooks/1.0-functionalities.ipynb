# %% [markdown]
# # Launch rqt_graph

# %%
# !bash -c "source ../../../install/setup.bash && rqt_graph"
# Out:
# [INFO] [1760728467.234061400] [rclcpp]: signal_handler(signum=2)
# ^C
# [INFO] [1760728467.284959933] [rclcpp]: signal_handler(signum=2)

# %%
# !bash -c "source ../../../install/setup.bash && ros2 topic list"
# Out:
# /number
# /parameter_events
# /rosout

# %%
# !bash -c "source ../../../install/setup.bash && ros2 topic info /number"
# Out:
# Type: example_interfaces/msg/Int64
# Publisher count: 1
# Subscription count: 1

# %%
# !bash -c "source ../../../install/setup.bash && ros2 interface show example_interfaces/msg/Int64"
# Out:
# # This is an example message of using a primitive datatype, int64.
# # If you want to test with this that's fine, but if you are deploying
# # it into a system you should create a semantically meaningful message type.
# # If you want to embed it in another message, use the primitive data type instead.
# int64 data

# %% [markdown]
# # Subscribe to a topic from terminal

# %%
# !bash -c "source ../../../install/setup.bash && ros2 topic echo /number"
# Out:
# data: 1
# ---
# data: 1
# ---
# data: 1
# ---
# data: 1
# ---
# data: 1
# ---
# data: 1
# ---
# ^C

# %% [markdown]
# # Publish to a topic from terminal

# %%
# !bash -c "source ../../../install/setup.bash && ros2 topic pub -r 1.0 /number example_interfaces/msg/Int64 '{data: 7}'"
# Out:
# publisher: beginning loop
# publishing #1: example_interfaces.msg.Int64(data=7)
#
# publishing #2: example_interfaces.msg.Int64(data=7)
#
# publishing #3: example_interfaces.msg.Int64(data=7)
#
# publishing #4: example_interfaces.msg.Int64(data=7)
#
# publishing #5: example_interfaces.msg.Int64(data=7)
#
# publishing #6: example_interfaces.msg.Int64(data=7)
#
# publishing #7: example_interfaces.msg.Int64(data=7)
#
# publishing #8: example_interfaces.msg.Int64(data=7)
#
# publishing #9: example_interfaces.msg.Int64(data=7)
#
# publishing #10: example_interfaces.msg.Int64(data=7)
#
# publishing #11: example_interfaces.msg.Int64(data=7)
#
# publishing #12: example_interfaces.msg.Int64(data=7)
#
# publishing #13: example_interfaces.msg.Int64(data=7)
#
# publishing #14: example_interfaces.msg.Int64(data=7)
#
# ^C
