# %% [markdown]
# # Creating bag folder

# %%
import os

ROOT_PATH = "../../../../"
os.listdir(ROOT_PATH)

# !mkdir "../../../../bags"

# %%
# !bash -c "cd '../../../../' && ls"
# Out:
# bags  ros2_ws

# %%
# !bash -c "cd '../../../../' && source ros2_ws/install/setup.bash && cd bags && ros2 bag record /number -o bag1"
# Out:
# [INFO] [1760729672.044219708] [rosbag2_recorder]: Press SPACE for pausing/resuming
# [INFO] [1760729672.048333123] [rosbag2_storage]: Opened database 'bag1/bag1_0.db3' for READ_WRITE.
# [INFO] [1760729672.052379537] [rosbag2_recorder]: Listening for topics...
# [INFO] [1760729672.052396262] [rosbag2_recorder]: Event publisher thread: Starting
# [INFO] [1760729672.053206435] [rosbag2_recorder]: Recording...
# [INFO] [1760729672.165258224] [rosbag2_recorder]: Subscribed to topic '/number'
# [INFO] [1760729672.165441413] [rosbag2_recorder]: All requested topics are subscribed. Stopping discovery...
# [INFO] [1760729709.658655268] [rosbag2_cpp]: Writing remaining messages from cache to the bag. It may take a while
# [INFO] [1760729709.659272212] [rosbag2_recorder]: Event publisher thread: Exiting
# [INFO] [1760729709.659418309] [rosbag2_recorder]: Recording stopped

# %%
# !bash -c "cd '../../../../' && source ros2_ws/install/setup.bash && ros2 bag play bags/bag1"
# Out:
# [INFO] [1760729803.611813792] [rosbag2_storage]: Opened database 'bags/bag1/bag1_0.db3' for READ_ONLY.
# [INFO] [1760729803.611873984] [rosbag2_player]: Set rate to 1
# [INFO] [1760729803.614899425] [rosbag2_player]: Adding keyboard callbacks.
# [INFO] [1760729803.614958006] [rosbag2_player]: Press SPACE for Pause/Resume
# [INFO] [1760729803.614964211] [rosbag2_player]: Press CURSOR_RIGHT for Play Next Message
# [INFO] [1760729803.614968574] [rosbag2_player]: Press CURSOR_UP for Increase Rate 10%
# [INFO] [1760729803.614972313] [rosbag2_player]: Press CURSOR_DOWN for Decrease Rate 10%
# [INFO] [1760729803.615430335] [rosbag2_storage]: Opened database 'bags/bag1/bag1_0.db3' for READ_ONLY.
